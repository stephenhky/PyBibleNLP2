# %%
import numpy as np
import pandas as pd
import util.corpus_io as cio
from gensim.models import TfidfModel, LsiModel

# %%
bchapcorpus, bchapdict = cio.load_corpus('/Users/stephenhky/Data/Bible/ESV/ESV_book_pipeline1')
bchaplabels = cio.load_doclabel('/Users/stephenhky/Data/Bible/ESV/ESV_chap_pipeline1_doclabels.txt')

# %%
bchaptfidf = TfidfModel(bchapcorpus)

# %%
lsimodel = LsiModel(bchaptfidf[bchapcorpus], num_topics=100, id2word=bchapdict.id2token)

# %%
bchaptfidf[bchapcorpus]
